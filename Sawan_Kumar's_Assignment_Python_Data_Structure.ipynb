# %%
# Name : Sawan Kumar
# Cource : Data Science with Generative AI
# Assignment : Python - Data Structure
# Module : 4



# Theory Questions



# 1. What are data structures, and why are they important?
  - Data structures are ways to organizing and storing data so that it can be accessed and manipulating efficiently.
  They are important because -
    > they allow programs to manage and manipulate data efficiently,
    > improving performance and optimizing memory usage.

# 2. Explain the difference between mutable and immutable data types with examples.
  - Mutable Data Types: Whose state or vlaue can be changed after they are created.
    - Example:
    > Lists ,
    > Dictionaries
  - Immutable Data Types: Whose state or vlaue can not be changed after they are created..
    - Example:
    > Strings ,
    > Tuples

# 3. What are the main differences between lists and tuples in Python?
  - Lists:
    > Mutable
    > Enclosed by square bracket '[]'
    > Uses more memory

  - Tuples:
    > Immutable
    > Enclosed by parentheses '()'
    > Uses less memory

# 4. Describe how dictionaries store data.
  - Dictionaries store data as key-value pairs.
    > The keys are unique and immutable.

# 5. Why might you use a set instead of a list in Python?
  - Use a set instead of a list in Python because -
    > Sets doesn't allow duplicate elements ,
    > in operator works faster in sets than in lists

# 6. What is a string in Python, and how is it different from a list?
  - A string is a sequence of characters, whereas a list can store different data types.
  - Strings are immutable, while lists are mutable.

# 7. How do tuples ensure data integrity in Python?
  - Tuples are immutable so it is ensuring data consistency.

# 8. What is a hash table, and how does it relate to dictionaries in Python?
  - A hash table is a data structure that maps keys to values using a hash function.
    > Python dictionaries are implemented using hash tables for efficient key-based lookups.

# 9. Can lists contain different data types in Python?
  - Yes,
    > lists contain different data types in Python such as integers, strings etc.

# 10. Explain why strings are immutable in Python.
  - Strings are immutable in python due to following reason -
    > enhance performance,
    > makes input/data more secure, and
    > preventing unintentional modifications.

# 11. What advantages do dictionaries offer over lists for certain tasks?
  - Advantages of dictionaries over lists for certain tasks are following -
    > Keys are unique and immutable
    > store data as key-value pairs
    > provide meaningful key-value associations,
    > making them ideal for structured data storage.

# 12. Describe a scenario where using a tuple would be preferable over a list.
  - Scenario where using a tuple is preferable over a list is following -
    > Where data is more crucial or important because tuples are immutable.

# 13. How do sets handle duplicate values in Python?
  - Sets doesn't allow duplicate elements so it is automatically remove duplicate values,
    > ensuring unique elements.

# 14. How does the “in” keyword work differently for lists and dictionaries?
  - Lists : used to test whether a certain value present in a list.
  - Dictionaries: it tells something appears or not as a key in the dictionary.

# 15. Can you modify the elements of a tuple? Explain why or why not.
  - No,
    > because tuples are immutable.

# 16. What is a nested dictionary, and give an example of its use case?
  - A nested dictionary is a dictionary in dictionary as a value.
    > Use case: Storing structured data like student records.

      res_menu = {"Momos": {"Veg": 125, "Nonveg": 170}}

# 17. Describe the time complexity of accessing elements in a dictionary.
  - The time complexity of retrieving a value by its key in a dictionary is O(1).

# 18. In what situations are lists preferred over dictionaries?
  - Situations where lists are preferred over dictionaries are following -
    > When data requires frequent modification becuase list are mutable ,
    > when work without key value pairs.

# 19. Why are dictionaries considered unordered, and how does that affect data retrieval?
  - Dictionaries are considered unordered because are designed for fast key-based retrieval
    > Affect on data retrieval : It becomes impossible to access elements by their position (index).

# 20. Explain the difference between a list and a dictionary in terms of data retrieval.
  - Lists : Retrieve elements by index (O(1)).
  - Dictionaries : Retrieve values using keys (O(1)) on average due to hashing.







# Practical Questions




# 1. Write a code to create a string with your name and print it.

    name = "Enter your name"
    print(name)  # Prints the string


# 2. Write a code to find the length of the string "Hello World".

    print(len("Hello World"))  # Prints 11


# 3. Write a code to slice the first 3 characters from the string "Python Programming".

    print("Python Programming"[:3])  # Prints 'Pyt'


# 4. Write a code to convert the string "hello" to uppercase.

    print("hello".upper())  # Prints 'HELLO'


# 5. Write a code to replace the word "apple" with "orange" in the string "I like apple".

    print("I like apple".replace("apple", "orange"))


# 6. Write a code to create a list with numbers 1 to 5 and print it.

    l1 = [1, 2, 3, 4, 5]
    print(l1)


# 7. Write a code to append the number 10 to the list [1, 2, 3, 4].

    num = [1, 2, 3, 4]
    num.append(10)
    print(num)


# 8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].

    num = [1, 2, 3, 4, 5]
    num.remove(3)
    print(num)


# 9. Write a code to access the second element in the list ['a', 'b', 'c', 'd'].

    letters = ['a', 'b', 'c', 'd']
    print(letters[1])  # Prints 'b'


# 10. Write a code to reverse the list [10, 20, 30, 40, 50].

    numbers = [10, 20, 30, 40, 50]
    numbers.reverse()
    print(numbers)


# 11. Write a code to create a tuple with the elements 100, 200, 300 and print it.

    t1 = (100, 200, 300)
    print(t1)


# 12. Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').

    colors = ('red', 'green', 'blue', 'yellow')
    print(colors[-2])  # Prints 'blue'


# 13. Write a code to find the minimum number in the tuple (10, 20, 5, 15).

    num = (10, 20, 5, 15)
    print(min(num))  # Prints 5


# 14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

    animals = ('dog', 'cat', 'rabbit')
    print(animals.index("cat"))  # Prints 1


# 15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.

    fruits = ('apple', 'banana', 'kiwi')
    print("kiwi" in fruits)  # Prints True


# 16. Write a code to create a set with the elements 'a', 'b', 'c' and print it.

    s = {'a', 'b', 'c'}
    print(s)


# 17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}.

    num = {1, 2, 3, 4, 5}
    num.clear()
    print(num)  # Prints set()


# 18. Write a code to remove the element 4 from the set {1, 2, 3, 4}.

    num = {1, 2, 3, 4}
    num.remove(4)
    print(num)


# 19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.

    set1 = {1, 2, 3}
    set2 = {3, 4, 5}
    print(set1|set2)  # Prints {1, 2, 3, 4, 5}


# 20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.

    print({1, 2, 3} & {2, 3, 4})  # Prints {2, 3}


# 21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it.

    emp = {"name": "Ramesh", "age": 54, "city": "Delhi"}
    print(emp)


# 22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.

    emp = {'name': 'John', 'age': 25}
    emp["country"] = "USA"
    print(emp)


# 23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.

    emp = {'name': 'Alice', 'age': 30}
    print(emp["name"])  # Prints 'Alice'


# 24. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.

    emp = {'name': 'Bob', 'age': 22, 'city': 'New York'}
    del emp["age"]
    print(emp)


# 25. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.

    emp = {'name': 'Alice', 'city': 'Paris'}
    print("city" in emp)  # Prints True


# 26. Write a code to create a list, a tuple, and a dictionary, and print them all.

    l1 = [1, 2, 3]
    t1 = (4, 5, 6)
    d1 = {"a": 7, "b": 8}
    print(l1, t1, d1)


# 27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.(replaced)

    import random
    random_numbers = [random.randint(1, 100) for _ in range(5)]
    random_numbers.sort()
    print(random_numbers)


# 28. Write a code to create a list with strings and print the element at the third index.

    l1 = ["Gandhi", "Patel", "Shubash", "Bhagat", "Sarojini"]
    print(l1[3])  # Prints 'Bhagat'


# 29. Write a code to combine two dictionaries into one and print the result.

    d1 = {"a": 1, "b": 2}
    d2 = {"c": 3, "d": 4}
    d1.update(d2)
    print(d1)


# 30. Write a code to convert a list of strings into a set.

    l1 = ["apple", "banana", "cherry", "apple"]
    print(set(l1))  # Removes duplicates >> {'cherry', 'apple', 'banana'}
